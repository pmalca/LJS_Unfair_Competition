# %%
import openai
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import os
import pickle
import time
openai.api_key = 'YOUR_API_KEY'  # Replace with your OpenAI API key

# %%
# Explaining the function that generates embeddings for a list of input texts using the OpenAI API.
# Explicando la función que genera los embeddings para una lista de textos de entrada utilizando la API de OpenAI.

def get_embeddings(texts):
    '''
    Generates embeddings for a list of input texts using the OpenAI API, handling token limits, rate limits, and connection timeouts.

    Parameters:
    -----------
    texts : list of str
        A list of textual data (documents, sentences, etc.) to generate embeddings for.

    Returns:
    --------
    np.array
        A NumPy array containing the embeddings for each input text.

    Functionality:
    --------------
    1. Splits input texts into smaller chunks based on the specified token limit (`max_tokens`).
    2. Sends each chunk to the OpenAI API to get embeddings, using the model specified (`text-embedding-3-small`).
    3. Handles potential errors:
        - `RateLimitError`: If the API rate limit is exceeded, waits for a specified time (`rate_limit_wait_time`) and retries.
        - `APIConnectionError`: If there is a connection issue, waits for a specified time (`timeout_wait_time`) and retries.
        - Other exceptions are caught and raised.
    4. Combines the embeddings from all chunks into a single NumPy array and returns it.

    Error Handling:
    ---------------
    - RateLimitError: Prints a message and waits before retrying.
    - APIConnectionError: Prints a message and waits before retrying.
    - Any other error is raised after printing the error message.
    '''

    max_tokens = 8192  # Define max tokens per request
    rate_limit_wait_time = 60  # Time to wait in seconds if rate limit is hit
    timeout_wait_time = 20  # Time to wait in seconds if a timeout occurs


    def split_texts(texts, max_tokens):
        chunks = []
        current_chunk = []
        current_length = 0
        for text in texts:
            text_length = len(text.split())  # Word count
            if current_length + text_length > max_tokens:
                chunks.append(current_chunk)
                current_chunk = [text]
                current_length = text_length
            else:
                current_chunk.append(text)
                current_length += text_length
        if current_chunk:
            chunks.append(current_chunk)
        return chunks
    

    def get_embeddings_for_chunk(chunk):
        while True:
            try:
                response = openai.Embedding.create(
                    model="text-embedding-3-small",  # Choose appropriate model
                    input=chunk
                )
                return [data['embedding'] for data in response['data']]
            except openai.error.RateLimitError:
                print(f"Rate limit exceeded. Waiting for {rate_limit_wait_time} seconds...")
                time.sleep(rate_limit_wait_time)
            except openai.error.APIConnectionError:
                print(f"Connection timed out. Waiting for {timeout_wait_time} seconds...")
                time.sleep(timeout_wait_time)
            except Exception as e:
                print(f"An error occurred: {e}")
                raise


    # Split texts into chunks and get embeddings
    chunks = split_texts(texts, max_tokens)
    embeddings = []
    for chunk in chunks:
        embeddings.extend(get_embeddings_for_chunk(chunk))

    return np.array(embeddings)

# %%
embeddings_path = r'corpus_ccd_embeddings_full.pkl' # Load your embeddings here

print("Loading stored embeddings and metadata...")
with open(embeddings_path, 'rb') as file:
    data = pickle.load(file)
    summary_embeddings = data['summary_embeddings']
    saved_metadata = data['metadata']
    saved_summaries = data['summaries']
# Out:
# Loading stored embeddings and metadata...

# %%
def find_relevant_summaries(query, top_k=10):
    '''
    Finds the most relevant summaries for a given query by computing cosine similarity between the query embedding and precomputed summary embeddings.

    Parameters:
    -----------
    query : str
        The query text for which relevant summaries need to be found.
    
    top_k : int, optional (default=8)
        The number of top relevant summaries to return based on cosine similarity.

    Returns:
    --------
    list of int
        A list of indices corresponding to the top `top_k` most relevant summaries, sorted by descending cosine similarity.

    Functionality:
    --------------
    1. Converts the input query into an embedding using the `get_embeddings` function.
    2. Computes cosine similarities between the query embedding and the precomputed summary embeddings (`summary_embeddings`).
    3. Sorts the similarities in descending order and selects the top `top_k` most relevant summaries.
    4. Returns the indices of the most relevant summaries.

    Notes:
    ------
    - Assumes that `summary_embeddings` is a global variable containing the embeddings for the summaries.
    - The higher the cosine similarity, the more relevant the summary is to the query.
    '''
    query_embedding = get_embeddings([query])[0]
    cos_similarities = cosine_similarity([query_embedding], summary_embeddings)[0]
    top_indices = cos_similarities.argsort()[-top_k:][::-1]
    return top_indices

# %%
# Example query
query = input("")

# Retrieve relevant summaries
top_indices = find_relevant_summaries(query)

# Prepare the relevant information from summaries and texts
relevant_info = []
for idx in top_indices:
    summary = saved_summaries[idx]
    row_metadata = saved_metadata.iloc[idx]

    relevant_info.append(f"Resolución: {row_metadata['Número de Resolución']}\nFecha de Resolución:{row_metadata['Fecha de Resolución']}\nHechos: {summary}\nEnlace: {row_metadata['Enlace']}")


# Combine relevant information into a single prompt for the LLM
combined_info = "\n\n".join(relevant_info)

def generate_response(prompt):
    '''
    Generates a legal analysis response based on a given prompt using the OpenAI basic GPT-4o-mini for legal tasks.

    Parameters:
    -----------
    prompt : str
        The input text or query for which the response will be generated. This could be a description of a legal case or a set of facts for which jurisprudence is being analyzed.

    Returns:
    --------
    str
        The generated response containing the legal analysis, relevant facts, and a conclusion based on the input prompt.

    Functionality:
    --------------
    1. Sends a request to the OpenAI API using the `gpt-4o` model, with the system role providing specific instructions for legal drafting.
    2. The system prompt instructs the model to:
        - Identify the relevant facts and criteria from jurisprudence similar to the case.
        - Conduct a legal analysis and offer a conclusion.
    3. The user's input (`prompt`) is passed as the main content for the model to process.
    4. The response is generated with a maximum of 1200 tokens and a temperature of 0.8 for balanced creativity and coherence.
    5. Returns the content of the model's response.

    Notes:
    ------
    - The model used, `gpt-4o-mini`, is instructed to identify relevant jurisprudence and provide a legal conclusion.
    - The `temperature=0.8` ensures that the response is somewhat creative while remaining grounded in legal reasoning.
    '''

    response = openai.ChatCompletion.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "Eres un asistente experto en redacción legal. A partir de la Jurisprudencia Relevante, vas a identificar cuáles son los hechos y criterios de la Jurisprudencia Relevante que son más similares a los Hechos del Caso. Después de identificar, debes precisar el análisis jurídico pertinente y ofrecer una conclusión"},
            
            {"role": "user", "content": prompt}
        ],
        max_tokens=1200,
        temperature=0.7
    )
    return response.choices[0].message['content']

# Create the prompt with the relevant information and query
prompt = f"Hechos del Caso:\n\n {query} \n\n Jurisprudencia Relevante:\n\n{combined_info}"
response = generate_response(prompt)

# Output the response
print(f"Hechos del Caso: {query}\n\nInforme: {response}\n\nJurisprudencia Relevante: \n\n{combined_info}")
# Out:
# Hechos del Caso: Una municipalidad ha estado ofreciendo el servicio de veterinaria a los vecinos. Este consiste en desparasitación, peluquería y corte de uñas. ¿Es un acto de violación de normas?
#
# Informe: ### Identificación de Hechos y Criterios Similares
#
# #### Hechos del Caso:
# - Una municipalidad ofrece servicios veterinarios a los vecinos, incluyendo desparasitación, peluquería y corte de uñas.
# - Se pregunta si estos actos constituyen una violación de normas.
#
# #### Jurisprudencia Relevante:
# 1. **Resolución 94-2022-CCD-INDECOPI-CUS**:
#    - Se denuncia a la Municipalidad Distrital de San Jerónimo por ofrecer servicios veterinarios (esterilización, consultas, desparasitaciones) supuestamente en competencia con servicios privados.
#    - La comisión concluye que estos servicios son preventivos y no empresariales, por lo que no hay violación de normas.
#    - Se recomienda evaluar la autorización de funcionamiento, pero no se imponen sanciones.
#
# 2. **Resolución 144-2018-CCD**:
#    - Se distingue entre servicios veterinarios preventivos (no empresariales) y servicios empresariales.
#    - La comisión declara improcedente la imputación sobre servicios preventivos, pero fundada en parte respecto a servicios empresariales.
#    - Se impone una multa y se ordena cesar los servicios empresariales.
#
# 3. **Resolución 145-2018-CCD**:
#    - Se clasifica entre servicios veterinarios preventivos y empresariales.
#    - Los servicios preventivos no son considerados actividades empresariales.
#    - La municipalidad fue sancionada por ofrecer servicios empresariales sin autorización legal.
#
# 4. **Resolución 146-2018-CCD**:
#    - La comisión concluye que los servicios veterinarios preventivos son legítimos y no constituyen competencia desleal.
#    - Se justifica la intervención estatal en servicios preventivos por razones de salud pública.
#
# ### Análisis Jurídico Pertinente
#
# #### Normativa Aplicable:
# - **Artículo 60 de la Constitución Política del Perú**: Establece que el Estado solo puede realizar actividad empresarial subsidiaria bajo autorización expresa de ley.
# - **Decreto Legislativo Nº 1044 (Ley de Represión de la Competencia Desleal)**: Define que la actividad empresarial estatal debe ser subsidiaria y autorizada por ley.
#
# #### Criterios de la Jurisprudencia:
# 1. **Naturaleza Preventiva de los Servicios**:
#    - Los servicios veterinarios que tienen una finalidad preventiva (como desparasitación y consultas básicas) no son considerados actividades empresariales.
#    - Estos servicios se justifican en términos de salud pública y prevención de zoonosis, lo cual es un deber del Estado.
#
# 2. **Distinción entre Servicios Preventivos y Empresariales**:
#    - Los servicios de peluquería y corte de uñas pueden ser considerados no estrictamente preventivos y, dependiendo de su finalidad, podrían clasificarse como servicios empresariales.
#    - La prestación de servicios empresariales por parte del Estado requiere autorización legal y debe ser subsidiaria.
#
# 3. **Subsidiariedad y Autorización**:
#    - La municipalidad necesita autorización expresa para ofrecer servicios que tienen características empresariales.
#    - La intervención del Estado debe ser subsidiaria, es decir, debe intervenir solo cuando la iniciativa privada no satisface la demanda.
#
# 4. **Improcedencia de Denuncias**:
#    - Las denuncias son improcedentes cuando los servicios ofrecidos son de carácter preventivo y no empresarial.
#
# ### Conclusión
#
# En base a la jurisprudencia relevante, los servicios de desparasitación, peluquería y corte de uñas ofrecidos por la municipalidad pueden ser analizados de la siguiente manera:
#
# - **Desparasitación**: Es un servicio preventivo destinado a la salud pública y la prevención de zoonosis. No constituye una actividad empresarial y no viola normas según el artículo 60 de la Constitución y el Decreto Legislativo Nº 1044.
#
# - **Peluquería y Corte de Uñas**: Estos servicios pueden no ser estrictamente preventivos. Si se consideran servicios con finalidad estética y comercial, podrían clasificarse como actividades empresariales. En tal caso, la municipalidad debe contar con la autorización expresa para ofrecer estos servicios.
#
# **Recomendación**:
# - La municipalidad debe evaluar si los servicios de peluquería y corte de uñas pueden justificarse bajo una perspectiva de salud pública y prevención de zoonosis. Si no es posible, debería cesar su prestación o buscar la autorización correspondiente.
# - Se recomienda que la municipalidad asegure que todos los servicios ofrecidos cumplan con los requisitos legales y obtengan las autorizaciones necesarias para evitar violaciones de normas.
#
# Jurisprudencia Relevante:
#
# Resolución: 94-2022-CCD-INDECOPI-CUS
# Fecha de Resolución:2022-02-17 00:00:00
# Hechos: - denuncia y partes: el colegio médico veterinario del perú presentó una denuncia contra la municipalidad distrital de san jerónimo por presunta competencia desleal, alegando violación del artículo 60 de la constitución y el numeral 14.3 del decreto legislativo nº 1044. - hechos denunciados: la denuncia se centra en la creación de un centro veterinario municipal, que supuestamente ofrecía servicios que competían con los privados, incluyendo esterilizaciones y consultas veterinarias. - normativa aplicable: se citan el artículo 60 de la constitución política del perú y el artículo 14.3 del decreto legislativo nº 1044, que establece que la actividad empresarial estatal debe ser subsidiaria y autorizada por ley. - argumentos de la municipalidad: la municipalidad argumentó que sus servicios son de interés público y que no constituyen actividades empresariales, ya que se enfocan en la sanidad animal y prevención de zoonosis. - evaluación de servicios: se concluyó que los servicios ofrecidos (esterilizaciones, desparasitaciones, consultas) son de carácter preventivo y no empresariales, lo que justifica su prestación por parte del estado. - improcedencia de la denuncia: la comisión declaró improcedente la denuncia, determinando que los servicios no califican como actividades empresariales y, por lo tanto, no hay violación de normas. - recomendación: se recomendó evaluar el inicio de un procedimiento administrativo contra la municipalidad por no contar con la autorización de la dirección regional de salud y licencia de funcionamiento. - decisión final: la resolución concluye que no se impone sanción ni medidas correctivas, ya que no se configuró la infracción denunciada. comi sion de la ofici na regional del indecopi de cu sco resolución n°094 -2022/indecopi -cus exped iente nº 00 8-2021/ccd -indecopi -cus página 15 de 17 sobre el particular , cabe precisar que el informe n°034 -2021 -rth-dma -gma-mdsj /c y anexo n°04 presentado por el colegio médico v eterinari o en su den uncia , no cuenta con la firma y sello de l emisor que permita verificar que el mismo fue emitido por la municipalidad , por lo que dicho documento resulta insuficiente para acreditar los servicios que ofrece rían en el centro veter inario municipal . siendo así, no corresponde analizar los servicios indicados en dicho documento . sin perjuicio de ello, de la resolución de alcaldía n° 212 -2021 -mdsj/c , de fecha 27 de mayo de 202119, mediante la cual se incorpor ó 15 servicios no exclusivo s al texto único de servicios no exclusivos -tusne (en ade lante, el tusne ) de la municipalidad , referidos a los costos de los servicios que brinda el c entro veterinario munici pal20, y de la publicación mediante la red social facebook de la municipalidad de una quinta campaña veterinaria , donde se habría efectuado esteril izaciones y despar asitac iones21, se advierte la exist encia de los siguientes servicios denunciados por el colegio m édico ve terinario: - despar asitación in terna - despar asitación externa - consulta general - tratamiento (inyectable s básicos con los medicamentos disp uestos ) - curaciones (básicas , limpieza de piel, ácaros y otros ectoparásitos de herid as y más) animales hasta 10kg. - esterilizaci ones en tal sentido, el colegiado considera pertinente que, al encontrarse señalados en el tusne y en la red social facebook de la municipalidad determinados servicios materia de denuncia , corresponde que estos sean analiza dos. de la revisión de los servi cios veterinarios descritos precedent emente , se a precia que los mismos consisten en at enciones de tipo gen eral y preventivo que busca n enfrentar la zoonosis y la sobre población de perros y gatos , que podría n afectar la salud de las personas . siend o así , la desparasitaci ón tiene como ob jetivo eliminar los par ásitos que se alojan en las mascotas , para prevenir el con tagio de enfer medades en las personas . asimismo, los tratamiento s son medios que se utilizan para la curación de ...
# Enlace: https://servicio.indecopi.gob.pe/buscadorResoluciones/getDoc?docID=workspace://SpacesStore/b9862bb8-12a8-476d-865a-23c118b18e5f
#
# Resolución: 145-2018-CCD
# Fecha de Resolución:2018-08-22 00:00:00
# Hechos: - contexto legal: la resolución se basa en la ley de represión de la competencia desleal (decreto legislativo nº 1044) y el artículo 60 de la constitución política del perú, que establece que el estado solo puede realizar actividad empresarial subsidiaria bajo autorización expresa de ley. - imputación inicial: la municipalidad distrital de san isidro fue acusada de competencia desleal por ofrecer servicios veterinarios sin cumplir con los requisitos establecidos en la constitución, específicamente en relación con servicios que podrían considerarse empresariales. - clasificación de servicios: se determinó que algunos servicios veterinarios ofrecidos por la municipalidad son de carácter empresarial y otros son preventivos. los servicios preventivos, como vacunaciones y consultas veterinarias, no se consideran actividades empresariales. - decisión sobre actividades empresariales: la comisión concluyó que la municipalidad no tenía autorización legal para ofrecer servicios veterinarios de carácter empresarial, lo que constituye una violación a la normativa de competencia. - medidas correctivas: se ordenó a la municipalidad cesar de inmediato la prestación de servicios veterinarios que se consideren empresariales hasta que se cumplan los requisitos legales. - sanción impuesta: la municipalidad fue sancionada con una amonestación y se ordenó su inscripción en el registro de infractores de la comisión de fiscalización de la competencia desleal del indecopi. - plazo de cumplimiento: la municipalidad tiene un plazo de tres días hábiles para cumplir con la resolución, bajo apercibimiento de nuevas sanciones. - remisión a contraloría: se enviará copia de los actuados a la contraloría general de la república para que tome las acciones pertinentes. instituto naciona l de defensa de la competencia y de la protección de la propiedad intelectual calle de la prosa 104, san borja, lima 41 - perú telf: 224 7800 / fax: 224 0348 e-mail: postmaster@indecopi.go b.pe / web: www.indecopi.gob.pe 15 n° denominación del servicio justificación naturaleza parvovirus) 3 administración de tratamiento antiparasitario zoonosis / salud humana preventiva 4 aplicación para ectoparásitos (pulgas, garrapatas, etc) – mascotas pequeñas, medianas y grandes zoonosis / salud humana preventiva 5 eutanasia zoonosis / salud humana preventiva 6 curaciones pequeñas y grandes zoonosis / salu d humana preventiva - emergencia 7 inyectable subcutáneo, intramuscular, endovenoso zoonosis / salud humana preventiva 8 suturas pequeñas (1 -2 puntos) y suturas grandes (3 ó más puntos) zoonosis / salud humana preventiva – emergencia 9 corte de uñas, li mpieza de oído y bolsas anales zoonosis / salud humana preventiva 10 vacuna quíntuple, sextuple zoonosis / salud humana preventiva 11 implante de microchip electrónico para canes y/o felinos ius imperium identificación 12 quimioterapia (antibiótico, analgésicos, antinflamatorios) - curativos 13 intoxicaciones - curativos 14 sarna (incluye todas las aplicaciones) zoonosis / salud humana preventivo 15 amputaciones de cola por camada (hasta 15 días de nacido y de 15 a 45 días de nacido por cachorro) - estético 16 extirpación de tumores mamarios - curativos 17 castración de gato y perro zoonosis / salud humana preventiva 18 ovario histerectomía en perra y en gata zoonosis / salud humana preventiva 19 hematoma del pabellón auricular - curativos de lo anterior, se puede verificar que la municipalidad brinda servicios veterinarios que se encuentran vinculados con medidas específicas que busquen enfrentar la zoonosis que podría afectar la salud de las personas ; esto es, configuran servicios veterinarios d e índole preventivo. asimismo, en el caso específico de los servicios de suturas y curaciones , estos se realizan por lo general en el marco de una situación de emergencia en donde el animal tiene una herida abierta y alguna enfermedad respectivamente , por lo que constituyen servicios necesarios para evitar infecciones tanto en el anima ...
# Enlace: https://servicio.indecopi.gob.pe/buscadorResoluciones/getDoc?docID=workspace://SpacesStore/cc362f35-d9dd-463f-a096-db58d451ebe7
#
# Resolución: 148-2018-CCD
# Fecha de Resolución:2018-08-22 00:00:00
# Hechos: - imputación inicial: se imputa a la municipalidad distrital de la molina por competencia desleal, específicamente por violación de normas, en relación con la prestación de servicios veterinarios sin cumplir con los requisitos establecidos en el artículo 60 de la constitución política y el artículo 14.3 de la ley de represión de la competencia desleal. - servicios no empresariales: la comisión determina que algunos servicios veterinarios no son considerados actividades empresariales, ya que tienen un carácter asistencial y preventivo, vinculados a la salud pública y bienestar animal. - servicios empresariales identificados: se concluye que otros servicios veterinarios, como fluidoterapia y cirugía, son de naturaleza empresarial y deben ser prestados por el sector privado, ya que no cumplen con los requisitos de carácter preventivo o de emergencia. - falta de autorización: la municipalidad no cuenta con una ley expresa que autorice la prestación de servicios veterinarios de carácter empresarial, lo que constituye una infracción al artículo 60 de la constitución. - medida correctiva: se ordena a la municipalidad cesar de inmediato la prestación de los servicios veterinarios identificados como empresariales hasta que cumpla con los requisitos legales. - sanción: se sanciona a la municipalidad con una amonestación y se ordena su inscripción en el registro de infractores de la comisión de fiscalización de la competencia desleal. - plazo para cumplimiento: la municipalidad tiene un plazo de tres días hábiles para cumplir con la resolución, bajo apercibimiento de nuevas sanciones. - remisión a contraloría: se remiten los actuados a la contraloría general de la república para que tome las acciones pertinentes. instituto nacional de defen sa de la competencia y de la protección de la propiedad intelectual calle de la prosa 104, san borja, lima 41 - perú telf: 224 7800 / fax: 224 0348 e-mail: postmaster@indecopi.gob.pe / web: www.indecopi.gob.pe 16 n° denominación del ser vicio justificación naturaleza 15 internamiento de canes por noche (encontrados en la vía pública) ius imperium - 16 registro municipal de canes y/o felino s con microchip ius imperium identificación 17 registro municipal de canes y/o felinos sin microchip ius imperium identificación 18 colocación de microchip ius imperium identificación 19 adiestramiento canino - - 20 alquiler de campo agility - - de lo anterior, se puede verificar que la municipalidad brinda servicios veterinarios que se encuentran vinculados con medidas específicas que busquen enfrentar la zoonosis que podría afectar la salud de las personas; esto es, configuran servicios veterinario s de índole preventivo. asimismo, en el caso específico de los servicios de emergencia, estos se realizan por lo general en el marco de una situación extraordinaria, por lo que constituyen servicios necesarios para evitar contaminaciones tanto en el animal como en los seres humanos que estén en contacto con el mismo. de manera complementaria, es pertinente indicar que mediante el informe n° 088-2018/gee se destaca que los servicios son brindados a costo, conforme lo indicado a continuación: “(…) 40. las tarifas de los servicios veterinarios brindados por la veterinaria están determinadas a partir de “los costos reales por fármaco de los productos”, que no son muy altos. tal como se indicó en la entrevista por los representantes de la veterinaria municipal , la oferta de los servicios veterinarios tiene el fin únicamente de recuperar periódicamente la inversión que se hace para volver a comprar (dichos fármacos).” en ese sentido, se evidencia que la actividad desarrollada vinculada a brindar servicios p reventivos no produce ningún beneficio económico para la misma. de manera complementaria, la comisión comparte el contenido del referido informe respecto de que los servicios brindados por la municipalidad tienen una capacidad limitada, dirigiéndose principal mente a brindar servicios preventivos, conforme se obse ...
# Enlace: https://servicio.indecopi.gob.pe/buscadorResoluciones/getDoc?docID=workspace://SpacesStore/74801679-a7d0-4efd-b1db-914ceae15d5a
#
# Resolución: 148-2018-CCD
# Fecha de Resolución:2018-08-22 00:00:00
# Hechos: - imputación inicial: se imputa a la municipalidad distrital de la molina por competencia desleal, específicamente por violación de normas, en relación con la prestación de servicios veterinarios sin cumplir con los requisitos establecidos en el artículo 60 de la constitución política y el artículo 14.3 de la ley de represión de la competencia desleal. - servicios no empresariales: la comisión determina que algunos servicios veterinarios no son considerados actividades empresariales, ya que tienen un carácter asistencial y preventivo, vinculados a la salud pública y bienestar animal. - servicios empresariales identificados: se concluye que otros servicios veterinarios, como fluidoterapia y cirugía, son de naturaleza empresarial y deben ser prestados por el sector privado, ya que no cumplen con los requisitos de carácter preventivo o de emergencia. - falta de autorización: la municipalidad no cuenta con una ley expresa que autorice la prestación de servicios veterinarios de carácter empresarial, lo que constituye una infracción al artículo 60 de la constitución. - medida correctiva: se ordena a la municipalidad cesar de inmediato la prestación de los servicios veterinarios identificados como empresariales hasta que cumpla con los requisitos legales. - sanción: se sanciona a la municipalidad con una amonestación y se ordena su inscripción en el registro de infractores de la comisión de fiscalización de la competencia desleal. - plazo para cumplimiento: la municipalidad tiene un plazo de tres días hábiles para cumplir con la resolución, bajo apercibimiento de nuevas sanciones. - remisión a contraloría: se remiten los actuados a la contraloría general de la república para que tome las acciones pertinentes. instituto nacional de defen sa de la competencia y de la protección de la propiedad intelectual calle de la prosa 104, san borja, lima 41 - perú telf: 224 7800 / fax: 224 0348 e-mail: postmaster@indecopi.gob.pe / web: www.indecopi.gob.pe 14 llevarlas a consultorios veterinarios (12,6%) donde la atención no es del todo completa. 16. en ese contexto, desde el punto de vista del proveedor de servicios veterinarios, la estrategia por tratar de brindar un servicio integral es una práctica comercial claramente orientada a cu brir todas las necesidades de las mascotas con el objetivo de aumentar el número de prestaciones de servicios veterinarios y la asistencia frecuente de los usuarios para maximizar el beneficio económico de la empresa. 17. el servicio completo puede abarcar c onsultas básicas y complejas, intervenciones médicas o quirúrgicas menores y mayores, exámenes de laboratorio, imágenes (rayos x, ecografías, etc.), venta de medicamentos, venta de comida, peluquería, pet -shop, etc. (…) 19. de esta manera, es posible inferir que los usuarios suelen demandar un conjunto de servicios y productos (…). al respecto, contar con una amplia gama de servicios veterinarios puede ser determinante para la rentabilización de la inversión en una veterinaria, ya que en la medida que se pueda ofrecer un mix de servicios médicos y no médicos amplios será posible tanto la atracción de clientes como su visita frecuente a estos establecimientos. una oferta de servicios parcial, por ejemplo, limitada a un grupo de servicios médicos, haría más compl ejo la rentabilidad del negocio si es que no permite brindar un número importante de atenciones en el tiempo.” en atención a ello, es importante destacar que el referido informe identificó una clasificación de centros veterinarios, los cuales son: (i) los consultorios veterinarios, que se caracterizan por contar con una sala para consulta y pequeñas intervenciones médicas y quirúrgicas; (ii) las clínicas veterinarias, que se caracterizan por brindar tratamientos especializados, debiendo contar para ello con instalaciones independientes para intervenciones quirúrgicas, áreas de diagnóstico de laboratorio e imagenológico propio o concertado; y, (iii) los hospitales veterinarios, que se caracteriz ...
# Enlace: https://servicio.indecopi.gob.pe/buscadorResoluciones/getDoc?docID=workspace://SpacesStore/74801679-a7d0-4efd-b1db-914ceae15d5a
#
# Resolución: 148-2018-CCD
# Fecha de Resolución:2018-08-22 00:00:00
# Hechos: - imputación inicial: se imputa a la municipalidad distrital de la molina por competencia desleal, específicamente por violación de normas, en relación con la prestación de servicios veterinarios sin cumplir con los requisitos establecidos en el artículo 60 de la constitución política y el artículo 14.3 de la ley de represión de la competencia desleal. - servicios no empresariales: la comisión determina que algunos servicios veterinarios no son considerados actividades empresariales, ya que tienen un carácter asistencial y preventivo, vinculados a la salud pública y bienestar animal. - servicios empresariales identificados: se concluye que otros servicios veterinarios, como fluidoterapia y cirugía, son de naturaleza empresarial y deben ser prestados por el sector privado, ya que no cumplen con los requisitos de carácter preventivo o de emergencia. - falta de autorización: la municipalidad no cuenta con una ley expresa que autorice la prestación de servicios veterinarios de carácter empresarial, lo que constituye una infracción al artículo 60 de la constitución. - medida correctiva: se ordena a la municipalidad cesar de inmediato la prestación de los servicios veterinarios identificados como empresariales hasta que cumpla con los requisitos legales. - sanción: se sanciona a la municipalidad con una amonestación y se ordena su inscripción en el registro de infractores de la comisión de fiscalización de la competencia desleal. - plazo para cumplimiento: la municipalidad tiene un plazo de tres días hábiles para cumplir con la resolución, bajo apercibimiento de nuevas sanciones. - remisión a contraloría: se remiten los actuados a la contraloría general de la república para que tome las acciones pertinentes. instituto nacional de defen sa de la competencia y de la protección de la propiedad intelectual calle de la prosa 104, san borja, lima 41 - perú telf: 224 7800 / fax: 224 0348 e-mail: postmaster@indecopi.gob.pe / web: www.indecopi.gob.pe 15 es así, que en el caso se observe servicios distintos a los preventivos o los servicios veterinarios en caso de emergencia , estos se tratarán de servicios de carácter empresarial, por lo que para estos se realizará el análisis correspondiente para determinar si se ha infringido la ley de represión de la competenci a desleal. d. la naturaleza de los servicios brindados por la municipalidad en el presente caso, mediante oficio n° 013 -2017 -mdlm -gdh -sgdsso de fecha 3 de febrero de 2017, la municipalidad adjuntó la ordenanza n° 321 de fecha 6 de setiembre de 2016, la c ual tenía como anexo las listas de servicios brindados en exclusividad, dentro de las que se encontraba la lista de los servicios veterinarios, en la cual se consignaban diversos servicios, tales como: (i) consultas; (ii) corte de uñas; (iii) limpieza de oídos; (iv) aplicación de inyectables; (v) fluidoterapia; (vi) desparasitación externa con ivermectina; (vii) desparasitación oral interna; (viii) desparasitación externa con antipulgas; (ix) acto eutanásico; (x) est erilización canina o felina para hembras; (xi) castración canina o felina para machos; (xii) cirugía de otohematoma; y, (xiii) atención de emergencias veterinarias. en esa línea, para efectos del pre sente procedimiento , es pertinente esclarecer los tres (3) supuestos en los que una actividad estatal no calza dentro del supuesto de actividad empresarial: (i) cuando se trata de un deber del estado, de conformidad con la carta mag na; (ii) en los casos de funciones soberanas de ius imperi um del estado; y, (iii) en las actividades asistenciales o sociales. ahora bien, para poder delimitar si el servicio brindado es calificado como un deber del estado es necesario determinar en qué supuestos estamos frente a servicios veterinarios que teng an naturaleza preventiva y/o de emergencia (en tanto las atenciones en caso de emergencia tienen naturaleza preventiva respecto de las personas) . los servicios veterinarios de naturaleza preventiva consisten en detectar y  ...
# Enlace: https://servicio.indecopi.gob.pe/buscadorResoluciones/getDoc?docID=workspace://SpacesStore/74801679-a7d0-4efd-b1db-914ceae15d5a
#
# Resolución: 94-2022-CCD-INDECOPI-CUS
# Fecha de Resolución:2022-02-17 00:00:00
# Hechos: - denuncia y partes: el colegio médico veterinario del perú presentó una denuncia contra la municipalidad distrital de san jerónimo por presunta competencia desleal, alegando violación del artículo 60 de la constitución y el numeral 14.3 del decreto legislativo nº 1044. - hechos denunciados: la denuncia se centra en la creación de un centro veterinario municipal, que supuestamente ofrecía servicios que competían con los privados, incluyendo esterilizaciones y consultas veterinarias. - normativa aplicable: se citan el artículo 60 de la constitución política del perú y el artículo 14.3 del decreto legislativo nº 1044, que establece que la actividad empresarial estatal debe ser subsidiaria y autorizada por ley. - argumentos de la municipalidad: la municipalidad argumentó que sus servicios son de interés público y que no constituyen actividades empresariales, ya que se enfocan en la sanidad animal y prevención de zoonosis. - evaluación de servicios: se concluyó que los servicios ofrecidos (esterilizaciones, desparasitaciones, consultas) son de carácter preventivo y no empresariales, lo que justifica su prestación por parte del estado. - improcedencia de la denuncia: la comisión declaró improcedente la denuncia, determinando que los servicios no califican como actividades empresariales y, por lo tanto, no hay violación de normas. - recomendación: se recomendó evaluar el inicio de un procedimiento administrativo contra la municipalidad por no contar con la autorización de la dirección regional de salud y licencia de funcionamiento. - decisión final: la resolución concluye que no se impone sanción ni medidas correctivas, ya que no se configuró la infracción denunciada. comi sion de la ofici na regional del indecopi de cu sco resolución n°094 -2022/indecopi -cus exped iente nº 00 8-2021/ccd -indecopi -cus página 4 de 17 el mencion ado informe n°034 -2021 -rth-dma -ga-mdsj/c, que presenta como documento adjunto , no posee firma de recepción del ge rente ( jefe inmediato), y tampoco posee el sello y firma del emisor ( jefe de la división de medio ambiente ), por tal motivo se desconoce dichos documento s presentes en e l expediente 008-2021/ccd -indecopi - cus, p uesto que no poseen sello ni firma par a dar validez al contenido dentr o de est os y por lo tanto no se acredita su originali dad de los docu mentos anex ados. (…) (…) según los documento s originales y lo s servicios por el que se est á realizando el contrato del médico veterinario son el de esteril izaciones qui rúrgicas para los an imales de compañías . y según las publicacio nes real izadas , los servicios que se desempeña en el centro veterinario m unicipal so n: - esterilizaciones de animales de compañía. - cons ultas básicas. - tratamientos básicos. - despar asitaciones básicas. y en ningún momento dentro de la s actividades del centro veterinario municipal , se desarrol la lo referente a estética canina, peluquería , pet shop, adiestramiento canino o albergue. dichas actividades menc ionadas son de orden subsidi arios y se e ncuentran presente en el tusne municipal con el objetivo de brindar un servicio a los vecinos jeronimianos . en pro de la ten encia responsable de animales de compañía , y el centro veter inario municipal no es considerado c omo comercio , y los servicios veteri narios que la ccd no consideró infractores ( competencia desleal ) (…). (…) de acuerdo al funcionamien to de l centro veter inario toda paciente que sufre u na cirugía de esterilizac ión debe recibir una dosis e antibióti cos y desinflamante de forma inyectabl e, y luego recibir una recet a médic a veterinaria p ara darle como tratamiento post operat orio al animal pacien te, por tal motivo a todos los animales qu e reciben el servicio de esterilización sea macho o hembra por recomendación del m édico veter inario josé ari as flores cmvp 11 91, y del médico veterinario luis a ngel morales caviedes con cmvp 4627 , se le entrega una receta post operatoria que debe seguirse por parte d ...
# Enlace: https://servicio.indecopi.gob.pe/buscadorResoluciones/getDoc?docID=workspace://SpacesStore/b9862bb8-12a8-476d-865a-23c118b18e5f
#
# Resolución: 94-2022-CCD-INDECOPI-CUS
# Fecha de Resolución:2022-02-17 00:00:00
# Hechos: - denuncia y partes: el colegio médico veterinario del perú presentó una denuncia contra la municipalidad distrital de san jerónimo por presunta competencia desleal, alegando violación del artículo 60 de la constitución y el numeral 14.3 del decreto legislativo nº 1044. - hechos denunciados: la denuncia se centra en la creación de un centro veterinario municipal, que supuestamente ofrecía servicios que competían con los privados, incluyendo esterilizaciones y consultas veterinarias. - normativa aplicable: se citan el artículo 60 de la constitución política del perú y el artículo 14.3 del decreto legislativo nº 1044, que establece que la actividad empresarial estatal debe ser subsidiaria y autorizada por ley. - argumentos de la municipalidad: la municipalidad argumentó que sus servicios son de interés público y que no constituyen actividades empresariales, ya que se enfocan en la sanidad animal y prevención de zoonosis. - evaluación de servicios: se concluyó que los servicios ofrecidos (esterilizaciones, desparasitaciones, consultas) son de carácter preventivo y no empresariales, lo que justifica su prestación por parte del estado. - improcedencia de la denuncia: la comisión declaró improcedente la denuncia, determinando que los servicios no califican como actividades empresariales y, por lo tanto, no hay violación de normas. - recomendación: se recomendó evaluar el inicio de un procedimiento administrativo contra la municipalidad por no contar con la autorización de la dirección regional de salud y licencia de funcionamiento. - decisión final: la resolución concluye que no se impone sanción ni medidas correctivas, ya que no se configuró la infracción denunciada. comi sion de la ofici na regional del indecopi de cu sco resolución n°094 -2022/indecopi -cus exped iente nº 00 8-2021/ccd -indecopi -cus página 14 de 17 sobre el informe n° 034 -2021 -rth-dma -gma -mdsj/c presentado por e l colegio médico veterinari o el colegio m édico veter inario señaló que el 29 de marzo de 20 21 tomó conocimiento del informe n° 034 -2021 -rth-dma -gma -mdsj/c emitido por el jefe de la división de medio ambiente de la municipalidad , por el cual solicita ron la contratación de un m édico veterinario para atender el centr o vet erinario municipal , con las siguientes indicaciones : - finalidad pública : contar con un profe sional técnico calificado en d icho centro para cubrir la demanda de la población en los temas de sanidad animal y zoono sis. - descripción del ser vicio: técnico profesio nal calificado. – médico veterinario colegiado , con capacidad de atención al cliente y capac itado en atención, como : (…) servicios denunciados: servicio de estética canina b ásica ( prevención zoo notica ). - solo se oto rgará para pacientes que poseen un sínd rome zoo nótico ( alopecia y/o ectoparásitos ), despar asitación in terna y externa : como protocolo de prevención de zoonosis y consultas médicas veterinarias: se realizarán las evaluaciones de los animales , diagnosticar y brind ar un tratamiento. - tratamiento : se realizará según el diagn óstico y las dosis re comendadas del medicamen to por el médi co veterinario. - curaciones : se podrá realizar curaciones de heri das según la eva luación del médico y el estado del animal. - perfil : médico veterinario y/o mé dico veterin ario-zootecnista colegiado y habilitado . capacitado en cirugías de esterilización de animales de compañ ía, consultas y tratamiento s. la municipalidad señaló que, en todas las publicaciones que realiza en su página de faceb ook (municipalidad de s an jerónimo -cusco @municipalidaddesan jeronimo - organ ización gubernamental ), se menciona que el centro veter inario otorga servicios de esteriliza ción, desparasitación , tratamiento s básicos y consultas médicas a costo social , servicios a disposición de la pobl ación jeronimiana. asimismo, refirió que el informe n°034 -2021 -rth-dma -gma-mdsj/c, que se presentó como documento adjunto en el escrito de denuncia , no pose ...
# Enlace: https://servicio.indecopi.gob.pe/buscadorResoluciones/getDoc?docID=workspace://SpacesStore/b9862bb8-12a8-476d-865a-23c118b18e5f
#
# Resolución: 144-2018-CCD
# Fecha de Resolución:2018-08-22 00:00:00
# Hechos: - imputación de competencia desleal: se declara improcedente en parte la imputación de la municipalidad distrital de ventanilla por competencia desleal, ya que ciertos servicios veterinarios no son actividades empresariales. sin embargo, se declara fundada en parte la imputación por otros servicios que sí tienen carácter empresarial, violando el artículo 60 de la constitución y el numeral 14.3 del decreto legislativo nº 1044. - normativa aplicable: se citan el artículo 60 de la constitución política del perú y el artículo 14.3 de la ley de represión de la competencia desleal, que establecen que el estado solo puede realizar actividad empresarial subsidiaria con autorización expresa de ley y en casos de alto interés público o conveniencia nacional. - servicios veterinarios: la comisión determina que algunos servicios veterinarios prestados por la municipalidad son de carácter empresarial, ya que no cumplen con los requisitos establecidos en la constitución. se ordena el cese inmediato de estos servicios hasta que se cumplan los requisitos legales. - medida correctiva y sanción: se impone una multa de 20 unidades impositivas tributarias a la municipalidad y se ordena su inscripción en el registro de infractores. además, se establece que la municipalidad debe cesar la prestación de servicios veterinarios calificados como empresariales. - justificación del estado: la defensa de la municipalidad se centra en que su actividad es de interés público y que actúa subsidiariamente debido a la falta de oferta privada. sin embargo, la comisión concluye que la actividad no se justifica bajo el principio de subsidiariedad, ya que existen servicios que pueden ser ofrecidos por el sector privado. - conclusión: la comisión resalta que la intervención del estado en actividades empresariales debe ser excepcional y siempre con base en una ley expresa, lo que no se cumple en este caso. se ordena la corrección de la situación y se sanciona a la municipalidad por la infracción cometida. instituto nacional d e defensa de la competencia y de la protección de la propiedad intelectual calle de la prosa 104, san borja, lima 41 - perú telf: 224 7800 / fax: 224 0348 e-mail: postmaster@indecopi.gob.pe / web: www.indecopi.gob.pe 22 sin embargo, este colegiado observa que determinados servicios veterinarios brindados por la municipalidad no califican como servicios preventivos y/o de ius imperium, tales como: n° denominación del servicio naturaleza 1 emisión de certificados (salud, vacunación, de observación clínica en general), de otras constancias de atención veterinaria, copia de historia clínica, duplicado de carnet de vac unas. documentaria 2 aplicación de tranquilizante y anestesia curativa 3 examen ocular tratamiento 4 sondaje uretral gatos tratamiento 5 tópico (monitoreos, toma de muestras en general, aplicación de inyectables y de quimioterapia) tratamiento 6 tratamiento de inyectables de prescripción (tratamientos inyectables, monitores, entre otros) tratamiento 7 radiografía complementario 8 ecografía complementario 9 anestesia general complementario 10 cirugía de hernias curativa 11 partos curativa 12 cirugía de abdomen y pelvis curativa 13 cirugía de cabeza curativa 14 movilidad y traslado para pacientes complementario 15 laboratorios 1 y 2 complementario 16 cirugía de piel y anexos curativa 17 cirugía de miembros y fracturas curativa 18 traumatolog ía y cirugía especializada asociada curativa 19 transfusión sanguínea curativa 20 baño y peluquería estética 21 farmacia y petshop en general complementario por lo tanto, la comisión observa que la municipalidad brinda servicios que no tienen la natur aleza de carácter preventivo, siendo que tampoco son actividades del ius imperium o actividades asistenciales (en sentido estricto, no se ha identificado un grupo vulnerable que permita concluir la calidad de actividad asistencial de dichos servicios), sie ndo que estos pueden ser prestados por centros veterinarios privados de manera independiente ...
# Enlace: https://servicio.indecopi.gob.pe/buscadorResoluciones/getDoc?docID=workspace://SpacesStore/5460a2d4-28dd-4326-8733-d971587790a3
#
# Resolución: 146-2018-CCD
# Fecha de Resolución:2018-08-22 00:00:00
# Hechos: - imputación de competencia desleal: se declara improcedente la imputación de la municipalidad distrital de san borja por presunta competencia desleal, específicamente por violación de normas, según el artículo 60 de la constitución y el numeral 14.3 del decreto legislativo nº 1044. - servicios veterinarios: la comisión concluye que los servicios veterinarios ofrecidos por la municipalidad no se consideran actividades empresariales, ya que son de carácter preventivo y están destinados a proteger la salud pública y la de los animales. - marco normativo: se citan normas relevantes, como el artículo 60 de la constitución, que establece que el estado puede realizar actividades empresariales solo con autorización de ley expresa y en casos de alto interés público o conveniencia nacional. también se menciona el artículo 14 de la ley de represión de la competencia desleal. - principio de subsidiariedad: la actuación del estado en la economía debe ser subsidiaria, es decir, solo intervenir cuando la iniciativa privada no satisface la demanda. la comisión considera que la municipalidad actúa en cumplimiento de sus deberes estatales y no como competidor en el mercado. - deberes del estado: se hace referencia a los deberes del estado en materia de salud, destacando la importancia de la salud pública veterinaria y la prevención de zoonosis, lo que justifica la intervención municipal en la prestación de servicios veterinarios. - naturaleza de los servicios: los servicios ofrecidos por la municipalidad, como consultas, inyectables y desparasitaciones, se consideran preventivos y necesarios para evitar infecciones y enfermedades, lo que refuerza la idea de que no constituyen actividad empresarial. - decisión final: la comisión, tras analizar la naturaleza de los servicios y el marco normativo, concluye que la municipalidad no incurre en competencia desleal y que su actuación es legítima y necesaria para el bienestar de la comunidad. instituto nacional de defensa de la competencia y de la protección de la propiedad intelectual calle de la prosa 104, san borja, lima 41 - perú telf: 224 7800 / fax: 224 0348 e-mail: postmaster@indecopi.go b.pe / web: www.indecopi.gob.pe 13 con una sala para consulta y pequeñas intervenciones médicas y quirúrgicas; (ii) las clínicas veterinarias, que se caracterizan por brindar tratamientos especializados, debiendo contar para ello con instalaciones independientes para intervenciones quirúrgicas, ár eas de diagnóstico de laboratorio e imagenológico propio o concertado; y, (iii) los hospitales veterinarios, que se caracterizan por contar de forma adicional a las clínicas veterinarias con una sala de hospitalización y de aislamiento. al respecto, este colegiado observa que por su naturaleza los consultorios veterinarios tienen características en los que se observa que se encuentran dirigidos a servicios básicos, por lo que en estos resulta posible una orientación para la prevención, mediante medidas es pecíficas que busquen enfrentar la zoonosis que podría afectar la salud de las personas. en este punto, la comisión considera oportuno destacar que aun en el caso se identifique que el establecimiento de la municipalidad se trate de un consultorio veterina rio, se debe verificar principalmente si los servicios brindados en la misma tienen la naturaleza de preventiva, dado que estos únicamente pueden ser brindados por el estado, conforme el análisis realizado previamente. es así, que en el caso se observe ser vicios distintos a los preventivos, estos se tratarán de servicios de carácter empresarial, por lo que para estos se realizará el análisis correspondiente para determinar si se ha infringido la ley de represión de la competencia desleal. e. la naturaleza de los servicios brindados por la municipalidad en el presente caso, personal de la secretaría técnica mediante las páginas web de la municipalidad tomó conocimiento que la imputada brindaba servicios veterinarios para mascotas; tales como: i) castración m ...
# Enlace: https://servicio.indecopi.gob.pe/buscadorResoluciones/getDoc?docID=workspace://SpacesStore/92665ec5-942d-4d1f-bf00-82c5b7f04727
#
# Resolución: 94-2022-CCD-INDECOPI-CUS
# Fecha de Resolución:2022-02-17 00:00:00
# Hechos: - denuncia y partes: el colegio médico veterinario del perú presentó una denuncia contra la municipalidad distrital de san jerónimo por presunta competencia desleal, alegando violación del artículo 60 de la constitución y el numeral 14.3 del decreto legislativo nº 1044. - hechos denunciados: la denuncia se centra en la creación de un centro veterinario municipal, que supuestamente ofrecía servicios que competían con los privados, incluyendo esterilizaciones y consultas veterinarias. - normativa aplicable: se citan el artículo 60 de la constitución política del perú y el artículo 14.3 del decreto legislativo nº 1044, que establece que la actividad empresarial estatal debe ser subsidiaria y autorizada por ley. - argumentos de la municipalidad: la municipalidad argumentó que sus servicios son de interés público y que no constituyen actividades empresariales, ya que se enfocan en la sanidad animal y prevención de zoonosis. - evaluación de servicios: se concluyó que los servicios ofrecidos (esterilizaciones, desparasitaciones, consultas) son de carácter preventivo y no empresariales, lo que justifica su prestación por parte del estado. - improcedencia de la denuncia: la comisión declaró improcedente la denuncia, determinando que los servicios no califican como actividades empresariales y, por lo tanto, no hay violación de normas. - recomendación: se recomendó evaluar el inicio de un procedimiento administrativo contra la municipalidad por no contar con la autorización de la dirección regional de salud y licencia de funcionamiento. - decisión final: la resolución concluye que no se impone sanción ni medidas correctivas, ya que no se configuró la infracción denunciada. comi sion de la ofici na regional del indecopi de cu sco resolución n°094 -2022/indecopi -cus exped iente nº 00 8-2021/ccd -indecopi -cus página 5 de 17 el centro veterinario municipal , realizando difusi ón por la s redes sociales propias de la municipalidad distr ital de san jerónimo , ofrece los servicios según el tusne -2021 y respet ando los reglamentos y norma tivas vigentes , y entre estos ofreciendo solamente : -vacunaci ones ( antirrábicas ) -esteri lización ova rio hiesterectomia ( animales hemb ras) -castraciones -cons ultas bási cas -tratamientos básicos. dichas actividades menciona das, son las actividades que se realizaron hasta la fecha , puesto que la log ística que se dispone a la fecha , no permite cumplir con o tras actividades permitida s según nor mativa. ( …) (…) el centro veter inario municipal según el expediente del proyecto “mejora miento del servicio del centro veter inario pa ra la atención de canidos y félidos domés ticos en la zona urbana y rural en el parque i de la urbanización inge nieros larapa grande del di strito de san jerónimo -provin cia de c usco – departamento de cusco ”. el proyecto se encuentra ubicado en el parque i de la urbanización ingenieros larapa del distrito de san jerónimo , el cual no cuenta c on las condiciones del servicio del c entro veter inario. (…) (…) dentro de l a estructura del centro veter inario municipal , no existe y no se consideró la construcción de jaul as, espacios, ambientes y/o lugares de transición de animales , donde se pueda brin dar el servicio de a lbergu e para animales o estadía de animales de compañía y tambi én mencionar que e l servicio de albergue u hospedaje es una activid ad considerad a como empresarial , por ello el centro veter inario munici pal no ejerce dicha actividad. (…) (…) el centro veter inario municipal no realizo , no realiza y no realizará la actividad de servicios pri vados de al bergues ni para animales ab andonas n i para an imales con dueños , porque el objetivo del centro ve terinario no es el de alb ergues y no tiene la logística necesaria para dicha actividad. los gobiernos local es tiene n la potestad de realizar actividades donde se puedan atender a todos los animal es dom ésticos y animales de compañía ( perros, gatos y otros ), en pro de la prevención d ...
# Enlace: https://servicio.indecopi.gob.pe/buscadorResoluciones/getDoc?docID=workspace://SpacesStore/b9862bb8-12a8-476d-865a-23c118b18e5f
